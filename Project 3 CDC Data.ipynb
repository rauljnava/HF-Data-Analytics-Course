# %%
#import Python packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
#import datasheet and save it in a dataframe
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
#EDA

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         encounter_id  patient_nbr   race  gender    age  weight  \
# 0              False        False  False   False  False   False
# 1              False        False  False   False  False   False
# 2              False        False  False   False  False   False
# 3              False        False  False   False  False   False
# 4              False        False  False   False  False   False
# ...              ...          ...    ...     ...    ...     ...
# 101761         False        False  False   False  False   False
# 101762         False        False  False   False  False   False
# 101763         False        False  False   False  False   False
# 101764         False        False  False   False  False   False
# 101765         False        False  False   False  False   False
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   False                     False                False
# ...

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
df.count()
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                        101766
# gender                      101766
# age                         101766
# weight                      101766
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                  101766
# medical_specialty           101766
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101766
# diag_2                      101766
# diag_3                      101766
# number_diagnoses            101766
# max_glu_serum               101766
# A1Cresult                   101766
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
df.max()
# Out:
# encounter_id                      443867222
# patient_nbr                       189502619
# race                                  Other
# gender                      Unknown/Invalid
# age                                [90-100)
# weight                             [75-100)
# admission_type_id                         8
# discharge_disposition_id                 28
# admission_source_id                      25
# time_in_hospital                         14
# payer_code                               WC
# medical_specialty                   Urology
# num_lab_procedures                      132
# num_procedures                            6
# num_medications                          81
# number_outpatient                        42
# number_emergency                         76
# number_inpatient                         21
# diag_1                                  V71
# diag_2                                  V86
# diag_3                                  V86
# ...

# %%
#Here, i've noticed that maximum value of 'time_in_hospital' is 14, which will be used as a reference value for this analysis

# %%
df['time_in_hospital'].max()
# Out:
# 14

# %%
#The other variable to analyze is 'diabetesMed'; which will be compared with 'time_in_hospital' = 14
df.groupby(['diabetesMed'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# diabetesMed
# Yes    78363
# No     23403
# Name: encounter_id, dtype: int64

# %%
#Determine unique identifier
df['encounter_id'].is_unique
# Out:
# True

# %%
#I will analyze how Medicated Patients correlate with Time in Hospital, select 'diabetesMed', 'time_in_hospital' and unique identifier 'encounter_id'
df2 = df[['encounter_id', 'diabetesMed', 'time_in_hospital']]

# %%
df2
# Out:
#         encounter_id diabetesMed  time_in_hospital
# 0            2278392          No                 1
# 1             149190         Yes                 3
# 2              64410         Yes                 2
# 3             500364         Yes                 2
# 4              16680         Yes                 1
# ...              ...         ...               ...
# 101761     443847548         Yes                 3
# 101762     443847782         Yes                 5
# 101763     443854148         Yes                 1
# 101764     443857166         Yes                10
# 101765     443867222          No                 6
#
# [101766 rows x 3 columns]

# %%
#Slicing "Yes" value in the 'diabetesMed' column
df3 = df2[df2['diabetesMed'].str.contains('Yes')]

# %%
#Slicing "No" value in the 'diabetesMed' column
df4 = df2[df2['diabetesMed'].str.contains('No')]

# %%
#Group 1 analysis: Diabetes medicated patients: Slicing 14 value in the 'time_in_hospital' column and selecting 
#'encounter_id' as unique identifier
df5 = df3[df3['time_in_hospital'] == 14]
df6 = df5[['time_in_hospital', 'encounter_id']]

# %%
#Counting total of group 1 patients with 14 days in the hospital. Storing result in a separate dataframe
#for further comparative analysis
df7 = df6.groupby(['time_in_hospital'])['encounter_id'].apply(pd.to_numeric).count()

# %%
df7
# Out:
# 853

# %%
#Group 2 analysis: Diabetes not medicated patients: Slicing 14 value in the 'time_in_hospital' 
#Counting total of group 1 patients with 14 days in the hospital. Storing result in a separate dataframe
#for further comparative analysis
df8 = df4[df4['time_in_hospital'] == 14]
df9 = df8.groupby(['time_in_hospital'])['encounter_id'].apply(pd.to_numeric).count()

# %%
df9
# Out:
# 189

# %%
#Create a data array to compare both group results
labels = ['With Diabetes Meds', 'Without Diabetes Meds']
my_data = [df7, df9]
arr = np.array(my_data)
d = {'With Diabetes Meds':df7, 'Without Diabetes Meds':df8}

# %%
df10 = pd.Series(data=my_data, index=labels)

# %%
df10
# Out:
# With Diabetes Meds       853
# Without Diabetes Meds    189
# dtype: int64

# %%
df10.plot(kind="bar", title='Diabetes Patients Hospitalized 14 Days', xlabel='Patients', ylabel='Patients')
# Out:
# <AxesSubplot:title={'center':'Diabetes Patients Hospitalized 14 Days'}, xlabel='Patients', ylabel='Patients'>
